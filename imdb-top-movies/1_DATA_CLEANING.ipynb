# %% [markdown]
# # DATA CLEANING

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./1_data/imdb_top_1000.csv')

# %%
df.head(1)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
#
#                Series_Title Released_Year Certificate  Runtime  Genre  \
# 0  The Shawshank Redemption          1994           A  142 min  Drama
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
#
#          Director        Star1           Star2       Star3           Star4  \
# 0  Frank Darabont  Tim Robbins  Morgan Freeman  Bob Gunton  William Sadler
#
#    No_of_Votes       Gross
# 0      2343110  28,341,469

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
# Removing the unnecessary columns
df.drop(['Poster_Link', 'Overview'], axis=1, inplace=True)

# %%
# Converting all columns to lowercase 
df.columns = df.columns.str.lower()

# %%
# Removing the 'min' from 'runtime' column
df['runtime'] = df['runtime'].str.replace(' min', '')

# %%
# Removing the ',' from 'gross' column
df['gross'] = df['gross'].str.replace(',', '')

# %%
# Converting data types
df[['released_year', 'runtime', 'gross']] = df[['released_year', 'runtime', 'gross']].astype('Int64')

# %%
# Counting the total number of null values in each column
null_counts = df.isnull().sum()
print('Total number of missing values by column:')
null_counts
# Out:
# Total number of missing values by column:
# series_title       0
# released_year      1
# certificate      101
# runtime            0
# genre              0
# imdb_rating        0
# meta_score       157
# director           0
# star1              0
# star2              0
# star3              0
# star4              0
# no_of_votes        0
# gross            169
# dtype: int64

# %%
# Counting the duplicated values
df.duplicated().sum()
# Out:
# 0

# %%
# Setting the 'series_title' as index
df.set_index('series_title', inplace=True)

# %%
df
# Out:
#                                  released_year certificate  runtime  \
# series_title
# Sleuth                                    1972          PG      138
# Nuovo Cinema Paradiso                     1988           U      155
# Happiness                                 1998         NaN      134
# Shadow of a Doubt                         1943          PG      108
# Planes, Trains & Automobiles              1987           U       93
# ...                                        ...         ...      ...
# Un long dimanche de fiançailles           2004           U      133
# Groundhog Day                             1993           U      101
# The Man Who Would Be King                 1975          PG      129
# Short Cuts                                1993           R      188
# Andhadhun                                 2018          UA      139
#
#                                                     genre  imdb_rating  \
# series_title
# Sleuth                                  Mystery, Thriller          8.0
# Nuovo Cinema Paradiso                      Drama, Romance          8.5
# Happiness                                   Comedy, Drama          7.7
# Shadow of a Doubt                     Film-Noir, Thriller          7.8
# Planes, Trains & Automobiles                Comedy, Drama          7.6
# ...                                                   ...          ...
# Un long dimanche de fiançailles   Drama, Mystery, Romance          7.6
# Groundhog Day                    Comedy, Fantasy, Romance          8.0
# The Man Who Would Be King         Adventure, History, War          7.8
# Short Cuts                                  Comedy, Drama          7.7
# Andhadhun                             Crime, Drama, Music          8.3
#
#                                  meta_score              director  \
# series_title
# Sleuth                                  NaN  Joseph L. Mankiewicz
# Nuovo Cinema Paradiso                  80.0    Giuseppe Tornatore
# Happiness                              81.0          Todd Solondz
# Shadow of a Doubt                      94.0      Alfred Hitchcock
# Planes, Trains & Automobiles           72.0           John Hughes
# ...                                     ...                   ...
# Un long dimanche de fiançailles        76.0    Jean-Pierre Jeunet
# Groundhog Day                          72.0          Harold Ramis
# The Man Who Would Be King              91.0           John Huston
# Short Cuts                             79.0         Robert Altman
# Andhadhun                               NaN       Sriram Raghavan
#
#                                               star1            star2  \
# series_title
# Sleuth                             Laurence Olivier    Michael Caine
# Nuovo Cinema Paradiso               Philippe Noiret   Enzo Cannavale
# Happiness                                Jane Adams       Jon Lovitz
# Shadow of a Doubt                     Teresa Wright    Joseph Cotten
# Planes, Trains & Automobiles           Steve Martin       John Candy
# ...                                             ...              ...
# Un long dimanche de fiançailles       Audrey Tautou   Gaspard Ulliel
# Groundhog Day                           Bill Murray  Andie MacDowell
# The Man Who Would Be King              Sean Connery    Michael Caine
# Short Cuts                          Andie MacDowell   Julianne Moore
# Andhadhun                        Ayushmann Khurrana             Tabu
#
#                                                   star3               star4  \
# series_title
# Sleuth                                   Alec Cawthorne       John Matthews
# Nuovo Cinema Paradiso                  Antonella Attili         Isa Danieli
# Happiness                        Philip Seymour Hoffman         Dylan Baker
# Shadow of a Doubt                       Macdonald Carey       Henry Travers
# Planes, Trains & Automobiles               Laila Robins      Michael McKean
# ...                                                 ...                 ...
# Un long dimanche de fiançailles            Jodie Foster     Dominique Pinon
# Groundhog Day                             Chris Elliott  Stephen Tobolowsky
# The Man Who Would Be King           Christopher Plummer       Saeed Jaffrey
# Short Cuts                                  Tim Robbins       Bruce Davison
# Andhadhun                                  Radhika Apte         Anil Dhawan
#
#                                  no_of_votes     gross
# series_title
# Sleuth                                 44748   4081254
# Nuovo Cinema Paradiso                 230763  11990401
# Happiness                              66408   2807390
# Shadow of a Doubt                      59556      <NA>
# Planes, Trains & Automobiles          124773  49530280
# ...                                      ...       ...
# Un long dimanche de fiançailles        70925   6167817
# Groundhog Day                         577991  70906973
# The Man Who Would Be King              44917      <NA>
# Short Cuts                             42275   6110979
# Andhadhun                              71875   1373943
#
# [1000 rows x 13 columns]

# %%
# Saving the clean file
df.to_csv('./1_data/imdb_top_1000_clean.csv')
