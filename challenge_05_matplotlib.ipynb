# %% [markdown]
# # Challenge 05 Matplotlib

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ## Task 2: Plot a quadratic function

# %%
# create a list of x values ranging from -10 to 10
x_values = list(range(-10, 11))

# %%
# create an empty list for the y values
y_values = []

# %%
# loop over the values of x and calculate y = x^2
for item in x_values:
    y = item ** 2
    y_values.append(y) 
print(y_values)
# Out:
# [100, 81, 64, 49, 36, 25, 16, 9, 4, 1, 0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
# Plotting the line plot
plt.plot(x_values, y_values, marker='o', linestyle='-')

# Adding labels and title
plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.title('y = x^2')

# Display the plot
plt.show()

# %% [markdown]
# ## Task 3: Plot your typical week

# %%
# create a list of weekdays:
x = ['Mo', 'Tu', 'We', 'Th', 'Fr', 'Sa', 'Su']

# %%
# For each day of the week write down the number of times you called someone and use those figures to make a list called y
y = [4, 3, 5, 6, 7, 8, 4]

# %%
plt.style.use('fivethirtyeight')

# %%
plt.bar(x, y, color =["steelblue", "green", "orange"])

# Adding labels and title
plt.xlabel('Days')
plt.ylabel('People Called')
plt.title('Number of Times I Called Somebody')

# Display the plot
plt.show()

# %% [markdown]
# ## Challenge - Visualize the Names Dataset

# %%
births_dict = {"year" : [], "total_births" : []}

# %%
def parse_dataset(value):
    path = f"../data/names/yob{value}.txt"
    df_year = pd.read_csv(path, names=["name", "gender", "frequency"])
    return df_year

# %%
# Create a plot of the summed up frequency (total births) per year from 1880 to 2020
for year in range(1880, 2021):
    df_year = parse_dataset(year)
    total_births = df_year["frequency"].sum()  # Calculate the sum of the frequencies
    births_dict['total_births'].append(total_births) # Append the result to the dictionary
    births_dict['year'].append(year) # Append the year to the dictionary
yearly_births = pd.DataFrame(births_dict) # Create a yearly_births DataFrame

# %%
yearly_births
# Out:
#      year  total_births
# 0    1880        201484
# 1    1881        192690
# 2    1882        221533
# 3    1883        216945
# 4    1884        243461
# ..    ...           ...
# 136  2016       3665860
# 137  2017       3572758
# 138  2018       3511750
# 139  2019       3465821
# 140  2020       3333981
#
# [141 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(10,6))
plt.plot(yearly_births["year"],yearly_births["total_births"], color = "steelblue")
plt.title("Total Births per Year")
plt.xlabel("Year")
plt.ylabel("Total Births")
plt.show()

# %% [markdown]
# ## Challenge - Visualize the Distribution of Names

# %%
# Read in a single dataset for one year using the parse_dataset() function
df2020 = parse_dataset(2020)

# %%
df2020.head(1)
# Out:
#      name gender  frequency
# 0  Olivia      F      17664

# %%
# create a histogram of the frequency column
plt.hist(df2020["frequency"], bins=50, color='steelblue', edgecolor='black', log=True)

plt.title("Frequency Distribution for 2020")
plt.xlabel('Frequency')
plt.ylabel('Number of Names')
plt.show()

# %%
df1950 = parse_dataset(1950)

# %%
plt.hist(df1950["frequency"], bins=50, color='steelblue', edgecolor='black', log=True)

plt.title("Frequency Distribution for 1950")
plt.xlabel('Frequency')
plt.ylabel('Number of Names')
plt.show()

# %%
# Top 10 most common name in 2020
df2020.sort_values("frequency", ascending=False).head(10)
# Out:
#             name gender  frequency
# 17485       Liam      M      19828
# 17486       Noah      M      18407
# 0         Olivia      F      17664
# 1           Emma      F      15680
# 17487     Oliver      M      14261
# 2            Ava      F      13179
# 17488     Elijah      M      13172
# 3      Charlotte      F      13083
# 4         Sophia      F      13070
# 5         Amelia      F      12780

# %%
# Top 10 most common name in 1950
df1950.sort_values("frequency", ascending=False).head(10)
# Out:
#           name gender  frequency
# 6110     James      M      86227
# 6111    Robert      M      83554
# 0        Linda      F      80431
# 6112      John      M      79417
# 1         Mary      F      65481
# 6113   Michael      M      65139
# 6114     David      M      60727
# 6115   William      M      60684
# 6116   Richard      M      51002
# 2     Patricia      F      47944

# %%
df2020.count()
# Out:
# name         31517
# gender       31517
# frequency    31517
# dtype: int64

# %%
df1950.count()
# Out:
# name         10305
# gender       10305
# frequency    10305
# dtype: int64

# %% [markdown]
# ## Challenge - Number of unique names over time

# %%
# How has the number of unique names given to newborn children varied over time?
# Initialize an empty dictionary to store results
unique_names_dict = {'year': [], 'unique_names_count': []}

# Loop through the years from 1880 to 2020
for year in range(1880, 2021):
    df = parse_dataset(year) # Read in the data for the current year
    unique_names_count = df['name'].nunique() # Calculate the number of unique names for the current year
    unique_names_dict['year'].append(year)    # Append the results to the dictionary
    unique_names_dict['unique_names_count'].append(unique_names_count)

unique_names_df = pd.DataFrame(unique_names_dict) # Convert the dictionary to a Pandas DataFrame

unique_names_df
# Out:
#      year  unique_names_count
# 0    1880                1889
# 1    1881                1829
# 2    1882                2012
# 3    1883                1962
# 4    1884                2158
# ..    ...                 ...
# 136  2016               30453
# 137  2017               30076
# 138  2018               29661
# 139  2019               29488
# 140  2020               28820
#
# [141 rows x 2 columns]

# %%
x = unique_names_df["year"]
y = unique_names_df["unique_names_count"]

# %%
# Visualize the data, use the years on the x-axis and the counts on the y-axis.
plt.figure(figsize=(10,6))
plt.bar(x, y, color=["steelblue"])
plt.title("Number of Unique Names Given to Newborns Over Time")
plt.xlabel("Year")
plt.ylabel("Number of Unique Names")

plt.show()

# %%
# Track my name over time
eytan = df_all["names"] == "Eytan"
df_eytan = df_all[eytan]

# %%
df_eytan.head(5)
# Out:
#         names gender  frequency  year
# 881274  Eytan      M          7  1980
# 920471  Eytan      M          7  1982
# 939804  Eytan      M          7  1983
# 958914  Eytan      M          8  1984
# 979406  Eytan      M          7  1985

# %%
x_eytan = df_eytan["year"]
y_eytan = df_eytan["frequency"]
color=["steelblue", "green"]

# %%
plt.figure(figsize=(10,6))
plt.bar(x_eytan, y_eytan, color="maroon")
plt.title("Number of 'Eytan' Over Time")
plt.xlabel("Year")
plt.ylabel("Number of 'Eytan'")

plt.show()

# %%
df2000 = parse_dataset(2000)

# %%
# Analyze the length of names for year 2000
# Add a new column 'name_length' to store the length of each name
df2000['name_length'] = df2000['name'].str.len()

# %%
df2000
# Out:
#           name gender  frequency  name_length
# 0        Emily      F      25957            5
# 1       Hannah      F      23085            6
# 2      Madison      F      19968            7
# 3       Ashley      F      17998            6
# 4        Sarah      F      17712            5
# ...        ...    ...        ...          ...
# 29771     Zeph      M          5            4
# 29772    Zeven      M          5            5
# 29773    Ziggy      M          5            5
# 29774       Zo      M          5            2
# 29775    Zyier      M          5            5
#
# [29776 rows x 4 columns]

# %%
# plot the distribution of the length of each name for a given year
plt.figure(figsize=(10,6))
plt.hist(df2000["name_length"], bins=40, color="green")

plt.title("Length Distribution of Each Name in 2000")
plt.xlabel('Frequency')
plt.ylabel('Number of Names')

plt.show()
